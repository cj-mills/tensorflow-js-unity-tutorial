# %% [markdown]
# **Uncomment the cell below if running on Google Colab or Kaggle**

# %%
# %%capture
# !pip3 install -U torch torchvision torchaudio
# !pip3 install -U fastai==2.7.9
# !pip3 install -U kaggle
# !pip3 install -U Pillow
# !pip3 install -U timm

# %%
# !pip install onnx-tf
# !pip install tensorflowjs
# !pip install tensorflow_probability
# !pip install onnx-simplifier
# !pip install simple-onnx-processing-tools
# !pip install -U onnx_graphsurgeon --index-url https://pypi.ngc.nvidia.com

# %% [markdown]
# **Note for Colab:**  You must restart the runtime in order to use newly installed version of Pillow.

# %% [markdown]
# **Import all fastai computer vision functionality**

# %%
from fastai.vision.all import *

# %%
import pandas as pd
pd.set_option('max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
import timm

# %%
timm.__version__
# Out:
# '0.6.7'

# %% [markdown]
# **Define model**

# %%
pd.DataFrame(timm.list_models('resnet*', pretrained=True))
# Out:
#                                  0
# 0                        resnet10t
# 1                        resnet14t
# 2                         resnet18
# 3                        resnet18d
# 4                         resnet26
# 5                        resnet26d
# 6                        resnet26t
# 7                       resnet32ts
# 8                       resnet33ts
# 9                         resnet34
# 10                       resnet34d
# 11                        resnet50
# 12                     resnet50_gn
# 13                       resnet50d
# 14                       resnet51q
# 15                       resnet61q
# 16                       resnet101
# 17                      resnet101d
# 18                       resnet152
# 19                      resnet152d
# 20                      resnet200d
# 21                      resnetaa50
# 22                    resnetblur50
# 23                      resnetrs50
# 24                     resnetrs101
# 25                     resnetrs152
# 26                     resnetrs200
# 27                     resnetrs270
# 28                     resnetrs350
# 29                     resnetrs420
# 30                     resnetv2_50
# 31               resnetv2_50d_evos
# 32                 resnetv2_50d_gn
# 33     resnetv2_50x1_bit_distilled
# 34              resnetv2_50x1_bitm
# 35        resnetv2_50x1_bitm_in21k
# 36              resnetv2_50x3_bitm
# 37        resnetv2_50x3_bitm_in21k
# 38                    resnetv2_101
# 39             resnetv2_101x1_bitm
# 40       resnetv2_101x1_bitm_in21k
# 41             resnetv2_101x3_bitm
# 42       resnetv2_101x3_bitm_in21k
# 43      resnetv2_152x2_bit_teacher
# 44  resnetv2_152x2_bit_teacher_384
# 45             resnetv2_152x2_bitm
# 46       resnetv2_152x2_bitm_in21k
# 47             resnetv2_152x4_bitm
# 48       resnetv2_152x4_bitm_in21k

# %%
from timm.models import resnet
resnet_model = 'resnet18'
resnet.default_cfgs[resnet_model]
# Out:
# {'url': 'https://download.pytorch.org/models/resnet18-5c106cde.pth',
#  'num_classes': 1000,
#  'input_size': (3, 224, 224),
#  'pool_size': (7, 7),
#  'crop_pct': 0.875,
#  'interpolation': 'bilinear',
#  'mean': (0.485, 0.456, 0.406),
#  'std': (0.229, 0.224, 0.225),
#  'first_conv': 'conv1',
#  'classifier': 'fc'}

# %%
pd.DataFrame(timm.list_models('convnext*', pretrained=True))
# Out:
#                                0
# 0                  convnext_base
# 1     convnext_base_384_in22ft1k
# 2         convnext_base_in22ft1k
# 3            convnext_base_in22k
# 4                 convnext_large
# 5    convnext_large_384_in22ft1k
# 6        convnext_large_in22ft1k
# 7           convnext_large_in22k
# 8                  convnext_nano
# 9                 convnext_small
# 10   convnext_small_384_in22ft1k
# 11       convnext_small_in22ft1k
# 12          convnext_small_in22k
# 13                 convnext_tiny
# 14    convnext_tiny_384_in22ft1k
# 15             convnext_tiny_hnf
# 16        convnext_tiny_in22ft1k
# 17           convnext_tiny_in22k
# 18  convnext_xlarge_384_in22ft1k
# 19      convnext_xlarge_in22ft1k
# 20         convnext_xlarge_in22k

# %%
from timm.models import convnext
convnext_model = 'convnext_nano'
convnext.default_cfgs[convnext_model]
# Out:
# {'url': 'https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/convnext_nano_d1h-7eb4bdea.pth',
#  'num_classes': 1000,
#  'input_size': (3, 224, 224),
#  'pool_size': (7, 7),
#  'crop_pct': 0.95,
#  'interpolation': 'bicubic',
#  'mean': (0.485, 0.456, 0.406),
#  'std': (0.229, 0.224, 0.225),
#  'first_conv': 'stem.0',
#  'classifier': 'head.fc',
#  'test_input_size': (3, 288, 288),
#  'test_crop_pct': 1.0}

# %%
pd.DataFrame(timm.list_models('mobilenetv2*', pretrained=True))
# Out:
#                   0
# 0   mobilenetv2_050
# 1   mobilenetv2_100
# 2  mobilenetv2_110d
# 3  mobilenetv2_120d
# 4   mobilenetv2_140

# %%
from timm.models import efficientnet
mobilenetv2_model = 'mobilenetv2_050'
efficientnet.default_cfgs[mobilenetv2_model]
# Out:
# {'url': 'https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/mobilenetv2_050-3d30d450.pth',
#  'num_classes': 1000,
#  'input_size': (3, 224, 224),
#  'pool_size': (7, 7),
#  'crop_pct': 0.875,
#  'interpolation': 'bicubic',
#  'mean': (0.485, 0.456, 0.406),
#  'std': (0.229, 0.224, 0.225),
#  'first_conv': 'conv_stem',
#  'classifier': 'classifier'}

# %%
pd.DataFrame(timm.list_models('mobilevitv2*', pretrained=True))
# Out:
#                                0
# 0                mobilevitv2_050
# 1                mobilevitv2_075
# 2                mobilevitv2_100
# 3                mobilevitv2_125
# 4                mobilevitv2_150
# 5   mobilevitv2_150_384_in22ft1k
# 6       mobilevitv2_150_in22ft1k
# 7                mobilevitv2_175
# 8   mobilevitv2_175_384_in22ft1k
# 9       mobilevitv2_175_in22ft1k
# 10               mobilevitv2_200
# 11  mobilevitv2_200_384_in22ft1k
# 12      mobilevitv2_200_in22ft1k

# %%
from timm.models import mobilevit
mobilevit_model = 'mobilevitv2_050'
mobilevit.default_cfgs[mobilevit_model]
# Out:
# {'url': 'https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-mvit-weights/mobilevitv2_050-49951ee2.pth',
#  'num_classes': 1000,
#  'input_size': (3, 256, 256),
#  'pool_size': (8, 8),
#  'crop_pct': 0.888,
#  'interpolation': 'bicubic',
#  'mean': (0.0, 0.0, 0.0),
#  'std': (1.0, 1.0, 1.0),
#  'first_conv': 'stem.conv',
#  'classifier': 'head.fc',
#  'fixed_input_size': False}

# %%
model_type = resnet
model_name = resnet_model
mean = model_type.default_cfgs[model_name]['mean']
std = model_type.default_cfgs[model_name]['std']
mean, std
# Out:
# ((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))

# %%
# model_type = convnext
# model_name = convnext_model
# mean = model_type.default_cfgs[model_name]['mean']
# std = model_type.default_cfgs[model_name]['std']
# mean, std

# %%
# model_type = efficientnet
# model_name = mobilenetv2_model
# mean = model_type.default_cfgs[model_name]['mean']
# std = model_type.default_cfgs[model_name]['std']
# mean, std

# %% [markdown]
# ### Kaggle API
# * [GitHub Repository](https://github.com/Kaggle/kaggle-api)
# * [Documentation](https://github.com/Kaggle/kaggle-api#competitions)
# * Install: `pip install kaggle`
# * Need to get an API Key for your Kaggle account
#     * [https://www.kaggle.com/me/account](https://www.kaggle.com/me/account)

# %% [markdown]
# **Enter Kaggle username and API token**

# %%
creds = '{"username":"","key":""}'

# %% [markdown]
# **Save Kaggle credentials if none are present**
# * **Source:** [https://github.com/fastai/fastbook/blob/master/09_tabular.ipynb](https://github.com/fastai/fastbook/blob/master/09_tabular.ipynb)

# %%
cred_path = Path('~/.kaggle/kaggle.json').expanduser()
# Save API key to a json file if it does not already exist
if not cred_path.exists():
    cred_path.parent.mkdir(exist_ok=True)
    cred_path.write_text(creds)
    cred_path.chmod(0o600)

# %% [markdown]
# **Import Kaggle API**

# %%
from kaggle import api

# %% [markdown]
# **Define method to display default function arguments**

# %%
import inspect
import pandas as pd
pd.set_option('max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

def inspect_default_args(target, annotations: bool=False):
    # Get the argument names
    args = inspect.getfullargspec(target).args
    # Get the default values
    defaults = inspect.getfullargspec(target).defaults

    index = ["Default Value"]

    # Pad defaults
    defaults = [None]*(len(args)-len(defaults)) + list(defaults)
    if annotations:
        index.append("Annotation")
        annotations = inspect.getfullargspec(target).annotations.values()
        # Pad annotations
        annotations = [None]*(len(args)-len(annotations)) + list(annotations)
        default_args = {arg:[df, annot] for arg,df,annot in zip(args, defaults, annotations)}
    else:
        default_args = {arg:[default] for arg,default in zip(args, defaults)}
        
    return pd.DataFrame(default_args, index=index).T

# %% [markdown]
# **Define path to dataset**

# %%
# dataset_name = 'hagrid-classification-512p-127k'
dataset_name = 'hagrid-classification-512p'
# dataset_name = 'hagrid-classification-512p-no-gesture'
kaggle_dataset = f'innominate817/{dataset_name}'
archive_dir = URLs.path()
dataset_dir = archive_dir/'../data'
archive_path = Path(f'{archive_dir}/{dataset_name}.zip')
dataset_path = Path(f'{dataset_dir}/{dataset_name}')

# %% [markdown]
# **Define method to extract the dataset from an archive file**

# %%
def file_extract(fname, dest=None):
    "Extract `fname` to `dest` using `tarfile` or `zipfile`."
    if dest is None: dest = Path(fname).parent
    fname = str(fname)
    if   fname.endswith('gz'):  tarfile.open(fname, 'r:gz').extractall(dest)
    elif fname.endswith('zip'): zipfile.ZipFile(fname     ).extractall(dest)
    else: raise Exception(f'Unrecognized archive: {fname}')

# %% [markdown]
# **Download the dataset if it is not present**

# %%
if not archive_path.exists():
    api.dataset_download_cli(kaggle_dataset, path=archive_dir)
    file_extract(fname=archive_path, dest=dataset_path)

# %% [markdown]
# **Inspect the dataset path**

# %%
dataset_path.ls()
# Out:
# (#1) [Path('/home/innom-dt/.fastai/archive/../data/hagrid-classification-512p/hagrid-classification-512p')]

# %% [markdown]
# **Get image file paths**

# %%
img_dir = dataset_path/dataset_name

# %%
files = get_image_files(img_dir)
len(files)
# Out:
# 509312

# %% [markdown]
# **Inspect files**

# %%
files[0], files[-1]
# Out:
# (Path('/home/innom-dt/.fastai/archive/../data/hagrid-classification-512p/hagrid-classification-512p/stop/3ac51cf4-cd81-4803-a608-76a55b36df26.jpeg'),
#  Path('/home/innom-dt/.fastai/archive/../data/hagrid-classification-512p/hagrid-classification-512p/two_up/1164cdc9-10ed-4032-afed-bbc5044148bd.jpeg'))

# %% [markdown]
# **Inspect class folder names**

# %%
folder_names = [path.name for path in Path(img_dir).ls()]
if 'models' in folder_names: 
    os.removedirs(img_dir/'models')
    folder_names.remove('models')
folder_names.sort()
print(f"Num classes: {len(folder_names)}")
pd.DataFrame(folder_names)
# Out:
# Num classes: 18
#                   0
# 0              call
# 1           dislike
# 2              fist
# 3              four
# 4              like
# 5              mute
# 6                ok
# 7               one
# 8              palm
# 9             peace
# 10   peace_inverted
# 11             rock
# 12             stop
# 13    stop_inverted
# 14            three
# 15           three2
# 16           two_up
# 17  two_up_inverted

# %% [markdown]
# **Inspect one of the training images**

# %%
import PIL
img = PIL.Image.open(files[0])
print(f"Image Dims: {img.shape}")
img
# Out:
# Image Dims: (512, 512)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %% [markdown]
# **Define target input dimensions**

# %%
# size_1_1 = (224, 224)
size_1_1 = (256, 256)
# size_1_1_large = (384, 384)
# size_3_2 = (224, 336)
# size_4_3 = (216, 288)
# size_16_9 = (216, 384)
# size_16_9_l = (288, 512)
size = size_1_1

# %% [markdown]
# **Define Transforms**

# %%
inspect_default_args(aug_transforms)
# Out:
#               Default Value
# mult                    1.0
# do_flip                True
# flip_vert             False
# max_rotate             10.0
# min_zoom                1.0
# max_zoom                1.1
# max_lighting            0.2
# max_warp                0.2
# p_affine               0.75
# p_lighting             0.75
# xtra_tfms              None
# size                   None
# mode               bilinear
# pad_mode         reflection
# align_corners          True
# batch                 False
# min_scale               1.0

# %%
item_tfms = [Resize(size, method=ResizeMethod.Pad, pad_mode=PadMode.Border)]

batch_tfms = [
    *aug_transforms(
        size=size, 
        mult=1.0,
        do_flip=True,
        flip_vert=False,
        max_rotate=0.0,
        min_zoom=1.0,
        max_zoom=1.1,
        max_lighting=0.2,
        max_warp=0.2, 
        p_affine=0.75,
        pad_mode=PadMode.Border)
]

# %% [markdown]
# **Define batch size**

# %%
bs = 32

# %% [markdown]
# **Define DataLoaders object**

# %%
inspect_default_args(ImageDataLoaders.from_folder)
# Out:
#            Default Value
# cls                 None
# path                None
# train              train
# valid              valid
# valid_pct           None
# seed                None
# vocab               None
# item_tfms           None
# batch_tfms          None

# %%
dls = ImageDataLoaders.from_folder(
    path=img_dir, 
    valid_pct=0.2, 
    bs=bs, 
    item_tfms=item_tfms, 
    batch_tfms=batch_tfms
)

# %% [markdown]
# **Verify DataLoaders object**

# %%
dls.train.show_batch()

# %%
dls.valid.show_batch()

# %% [markdown]
# **Inspect Learner parameters**

# %%
inspect_default_args(vision_learner)
# Out:
#                                             Default Value
# dls                                                  None
# arch                                                 None
# normalize                                            True
# n_out                                                None
# pretrained                                           True
# loss_func                                            None
# opt_func                <function Adam at 0x7f81742b9090>
# lr                                                  0.001
# splitter                                             None
# cbs                                                  None
# metrics                                              None
# path                                                 None
# model_dir                                          models
# wd                                                   None
# wd_bn_bias                                          False
# train_bn                                             True
# moms                                   (0.95, 0.85, 0.95)
# cut                                                  None
# init         <function kaiming_normal_ at 0x7f818269cc10>
# custom_head                                          None
# concat_pool                                          True
# pool                                                 True
# lin_ftrs                                             None
# ps                                                    0.5
# first_bn                                             True
# bn_final                                            False
# lin_first                                           False
# y_range                                              None

# %% [markdown]
# **Define [metrics](https://docs.fast.ai/metrics.html)**

# %%
metrics = [error_rate, accuracy]

# %% [markdown]
# **Define Learner object**

# %%
learn = vision_learner(dls, model_name, metrics=metrics)

# %% [markdown]
# **Find learning rate**

# %%
inspect_default_args(learn.lr_find)
# Out:
#                                      Default Value
# self                                          None
# start_lr                                       0.0
# end_lr                                          10
# num_it                                         100
# stop_div                                      True
# show_plot                                     True
# suggest_funcs  <function valley at 0x7f8173f2d750>

# %% [markdown]
# **Define [suggestion methods](https://docs.fast.ai/callback.schedule.html#Suggestion-Methods)**

# %%
suggest_funcs = [valley, minimum, steep]

# %%
learn.lr_find(suggest_funcs=suggest_funcs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0020892962347716093, minimum=0.006918309628963471, steep=0.02290867641568184)

# %% [markdown]
# **Define learning rate**

# %%
lr = 3e-3
lr
# Out:
# 0.003

# %% [markdown]
# **Define number of epochs**

# %%
epochs = 5

# %% [markdown]
# **Define callbacks**

# %%
cbs = [MixedPrecision()]

# %% [markdown]
# **Fine tune model**

# %%
inspect_default_args(learn.fine_tune)
# Out:
#               Default Value
# self                   None
# epochs                 None
# base_lr               0.002
# freeze_epochs             1
# lr_mult                 100
# pct_start               0.3
# div                     5.0

# %%
learn.fine_tune(epochs, base_lr=lr, cbs=cbs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.324472</td>
#       <td>0.186859</td>
#       <td>0.061377</td>
#       <td>0.938623</td>
#       <td>09:28</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.095332</td>
#       <td>0.066194</td>
#       <td>0.021745</td>
#       <td>0.978255</td>
#       <td>10:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.071527</td>
#       <td>0.043880</td>
#       <td>0.013891</td>
#       <td>0.986109</td>
#       <td>10:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.036878</td>
#       <td>0.031311</td>
#       <td>0.009709</td>
#       <td>0.990291</td>
#       <td>10:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.043266</td>
#       <td>0.026252</td>
#       <td>0.008246</td>
#       <td>0.991754</td>
#       <td>10:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.019016</td>
#       <td>0.024944</td>
#       <td>0.007736</td>
#       <td>0.992264</td>
#       <td>10:15</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Select a test image**

# %%
import PIL

# %%
test_file = files[0]
test_file.parent.name, test_file.name
# Out:
# ('stop', '3ac51cf4-cd81-4803-a608-76a55b36df26.jpeg')

# %%
test_img = PIL.Image.open(test_file)
test_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %% [markdown]
# **Make a prediction on a single image using a [fastai.vision.core.PILImage](https://docs.fast.ai/vision.core.html#PILImage)**

# %%
learn.predict(PILImage(test_img.transpose(Image.Transpose.FLIP_LEFT_RIGHT)))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('stop',
#  TensorBase(12),
#  TensorBase([7.3012e-09, 3.3731e-09, 8.7322e-09, 6.1065e-08, 1.1257e-08, 4.6104e-10,
#          1.6041e-11, 2.0950e-09, 6.8322e-06, 9.8094e-11, 1.7992e-11, 1.6419e-08,
#          9.9999e-01, 4.9768e-10, 1.4597e-10, 7.1182e-10, 3.4267e-10, 2.6045e-11]))

# %% [markdown]
# **Make predictions for a group of images**

# %%
learn.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# **Define an Interpretation object**

# %%
interp = Interpretation.from_learner(learn)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# **Plot top losses**

# %%
interp.plot_top_losses(k=9, figsize=(15,10))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# **Inspect the `after_item` pipeline**

# %%
learn.dls.after_item
# Out:
# Pipeline: Resize -- {'size': (256, 256), 'method': 'pad', 'pad_mode': 'border', 'resamples': (<Resampling.BILINEAR: 2>, <Resampling.NEAREST: 0>), 'p': 1.0} -> ToTensor

# %% [markdown]
# **Inspect the `after_batch` pipeline**

# %%
learn.dls.after_batch
# Out:
# Pipeline: IntToFloatTensor -- {'div': 255.0, 'div_mask': 1} -> Flip -- {'size': (256, 256), 'mode': 'bilinear', 'pad_mode': 'border', 'mode_mask': 'nearest', 'align_corners': True, 'p': 0.5} -> Brightness -- {'max_lighting': 0.2, 'p': 1.0, 'draw': None, 'batch': False} -> Normalize -- {'mean': tensor([[[[0.4850]],
#
#          [[0.4560]],
#
#          [[0.4060]]]], device='cuda:0'), 'std': tensor([[[[0.2290]],
#
#          [[0.2240]],
#
#          [[0.2250]]]], device='cuda:0'), 'axes': (0, 2, 3)}

# %% [markdown]
# **Reset test image**

# %%
test_img = PIL.Image.open(test_file)
test_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %%
test_img.size
# Out:
# (512, 512)

# %%
min(test_img.size)
# Out:
# 512

# %%
min_dim = test_img.size.index(min(test_img.size))
max_dim = 1 - min_dim

# %%
target_dim = 224

# %% [markdown]
# **Set input dims**

# %%
inp_dims = [0,0]
inp_dims[min_dim] = target_dim
inp_dims[max_dim] = int(test_img.size[max_dim] / (test_img.size[min_dim]/target_dim))
inp_dims
# Out:
# [224, 224]

# %%
resized_img = test_img.resize(inp_dims)
resized_img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# **Convert image to tensor**

# %%
img_tensor = tensor(resized_img).permute(2, 0, 1)
img_tensor.shape, img_tensor
# Out:
# (torch.Size([3, 224, 224]),
#  tensor([[[188, 186, 185,  ..., 179, 179, 180],
#           [190, 188, 186,  ..., 181, 179, 179],
#           [190, 191, 188,  ..., 181, 180, 180],
#           ...,
#           [252, 254, 254,  ..., 142, 142, 141],
#           [252, 254, 254,  ..., 142, 142, 142],
#           [252, 254, 254,  ..., 141, 142, 143]],
#
#          [[161, 160, 159,  ..., 134, 134, 134],
#           [162, 162, 161,  ..., 136, 134, 133],
#           [163, 164, 163,  ..., 137, 135, 135],
#           ...,
#           [249, 251, 251,  ..., 160, 160, 159],
#           [249, 251, 251,  ..., 160, 160, 160],
#           [249, 251, 251,  ..., 159, 160, 161]],
#
#          [[122, 123, 123,  ..., 104, 103, 101],
#           [123, 125, 124,  ..., 106, 103, 100],
#           [124, 127, 126,  ..., 106, 104, 102],
#           ...,
#           [232, 234, 234,  ..., 198, 198, 197],
#           [232, 234, 234,  ..., 198, 198, 198],
#           [232, 234, 234,  ..., 197, 198, 199]]], dtype=torch.uint8))

# %% [markdown]
# **Scale tensor values**

# %%
scaled_tensor = img_tensor.float().div_(255)

# %% [markdown]
# **Prepare mean values**

# %%
mean_tensor = tensor(mean).view(1,1,-1).permute(2, 0, 1)
mean_tensor.shape, mean_tensor
# Out:
# (torch.Size([3, 1, 1]),
#  tensor([[[0.4850]],
#
#          [[0.4560]],
#
#          [[0.4060]]]))

# %% [markdown]
# **Prepare std_dev values**

# %%
std_tensor = tensor(std).view(1,1,-1).permute(2, 0, 1)
std_tensor.shape, std_tensor
# Out:
# (torch.Size([3, 1, 1]),
#  tensor([[[0.2290]],
#
#          [[0.2240]],
#
#          [[0.2250]]]))

# %% [markdown]
# **Normalize and batch image tensor**

# %%
normalized_tensor = (scaled_tensor - mean_tensor) / std_tensor
batched_tensor = normalized_tensor.unsqueeze(dim=0)
batched_tensor.shape, batched_tensor
# Out:
# (torch.Size([1, 3, 224, 224]),
#  tensor([[[[ 1.1015,  1.0673,  1.0502,  ...,  0.9474,  0.9474,  0.9646],
#            [ 1.1358,  1.1015,  1.0673,  ...,  0.9817,  0.9474,  0.9474],
#            [ 1.1358,  1.1529,  1.1015,  ...,  0.9817,  0.9646,  0.9646],
#            ...,
#            [ 2.1975,  2.2318,  2.2318,  ...,  0.3138,  0.3138,  0.2967],
#            [ 2.1975,  2.2318,  2.2318,  ...,  0.3138,  0.3138,  0.3138],
#            [ 2.1975,  2.2318,  2.2318,  ...,  0.2967,  0.3138,  0.3309]],
#
#           [[ 0.7829,  0.7654,  0.7479,  ...,  0.3102,  0.3102,  0.3102],
#            [ 0.8004,  0.8004,  0.7829,  ...,  0.3452,  0.3102,  0.2927],
#            [ 0.8179,  0.8354,  0.8179,  ...,  0.3627,  0.3277,  0.3277],
#            ...,
#            [ 2.3235,  2.3585,  2.3585,  ...,  0.7654,  0.7654,  0.7479],
#            [ 2.3235,  2.3585,  2.3585,  ...,  0.7654,  0.7654,  0.7654],
#            [ 2.3235,  2.3585,  2.3585,  ...,  0.7479,  0.7654,  0.7829]],
#
#           [[ 0.3219,  0.3393,  0.3393,  ...,  0.0082, -0.0092, -0.0441],
#            [ 0.3393,  0.3742,  0.3568,  ...,  0.0431, -0.0092, -0.0615],
#            [ 0.3568,  0.4091,  0.3916,  ...,  0.0431,  0.0082, -0.0267],
#            ...,
#            [ 2.2391,  2.2740,  2.2740,  ...,  1.6465,  1.6465,  1.6291],
#            [ 2.2391,  2.2740,  2.2740,  ...,  1.6465,  1.6465,  1.6465],
#            [ 2.2391,  2.2740,  2.2740,  ...,  1.6291,  1.6465,  1.6640]]]]))

# %% [markdown]
# **Pass tensor to model**

# %%
with torch.no_grad():
    preds = learn.model.cuda()(batched_tensor.cuda())
preds
# Out:
# TensorBase([[ -6.7205,  -8.0564,  -7.9315,  -7.6230,  -8.1622, -11.5650, -12.8793,
#          -12.1175,  -1.4742, -12.4300, -13.0365,  -8.3919,  12.9647, -10.8745,
#          -12.0588, -10.1345, -10.6733, -13.0996]], device='cuda:0')

# %% [markdown]
# **Process model output**

# %%
torch.nn.functional.softmax(preds, dim=1)
# Out:
# TensorBase([[2.8237e-09, 7.4238e-10, 8.4116e-10, 1.1452e-09, 6.6788e-10, 2.2225e-11,
#          5.9712e-12, 1.2792e-11, 5.3609e-07, 9.3586e-12, 5.1027e-12, 5.3079e-10,
#          1.0000e+00, 4.4336e-11, 1.3564e-11, 9.2924e-11, 5.4218e-11, 4.7909e-12]],
#        device='cuda:0')

# %%
preds.argmax()
# Out:
# TensorBase(12, device='cuda:0')

# %%
torch.nn.functional.softmax(preds, dim=1)[0][preds.argmax()]
# Out:
# TensorBase(1.0000, device='cuda:0')

# %% [markdown]
# **Get the class labels**

# %%
learn.dls.vocab
# Out:
# ['call', 'dislike', 'fist', 'four', 'like', 'mute', 'ok', 'one', 'palm', 'peace', 'peace_inverted', 'rock', 'stop', 'stop_inverted', 'three', 'three2', 'two_up', 'two_up_inverted']

# %% [markdown]
# **Get the predicted class label**

# %%
learn.dls.vocab[torch.nn.functional.softmax(preds, dim=1).argmax()]
# Out:
# 'stop'

# %% [markdown]
# **Define ONNX opset version**

# %%
opset = 15

# %% [markdown]
# **Define ONNX file name**

# %%
onnx_file_name = f"{dataset_path.name}-{learn.arch}-opset{opset}.onnx"
print(onnx_file_name)
# Out:
# hagrid-classification-512p-resnet18-opset15.onnx

# %% [markdown]
# **Export trained model to ONNX**

# %%
torch.onnx.export(learn.model.cpu(),
                  batched_tensor,
                  onnx_file_name,
                  export_params=True,
                  opset_version=opset,
                  do_constant_folding=True,
                  input_names = ['input'],
                  output_names = ['output'],
                  dynamic_axes={'input': {2 : 'height', 3 : 'width'}}
                 )
# Out:
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/torch/onnx/symbolic_helper.py:719: UserWarning: allowzero=0 by default. In order to honor zero value in shape use allowzero=1
#   warnings.warn("allowzero=0 by default. In order to honor zero value in shape use allowzero=1")

# %% [markdown]
# **Export class labels**

# %%
labels = [label.replace("train_val_", "") for label in list(learn.dls.vocab)]
labels
# Out:
# ['call',
#  'dislike',
#  'fist',
#  'four',
#  'like',
#  'mute',
#  'ok',
#  'one',
#  'palm',
#  'peace',
#  'peace_inverted',
#  'rock',
#  'stop',
#  'stop_inverted',
#  'three',
#  'three2',
#  'two_up',
#  'two_up_inverted']

# %%
import json

class_labels = {"classes": labels}
class_labels_file_name = f"{dataset_path.name}-classes.json"

with open(class_labels_file_name, "w") as write_file:
    json.dump(class_labels, write_file)

# %% [markdown]
# **Export model normalization stats**

# %%
normalization_stats = {"mean": list(mean), "std": list(std)}
normalization_stats_file_name = f"{learn.arch}-normalization_stats.json"

with open(normalization_stats_file_name, "w") as write_file:
    json.dump(normalization_stats, write_file)

# %% [markdown]
# **Import dependencies for TensorFlow.js conversion**

# %%
import onnx
from scc4onnx import order_conversion
from onnxsim import simplify
from onnx_tf.backend import prepare
# Out:
# 2022-09-12 10:19:13.678124: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-12 10:19:14.087271: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-09-12 10:19:14.275887: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-09-12 10:19:15.052963: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-09-12 10:19:15.053026: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-09-12 10:19:15.053030: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /home/innom-dt/mambaforge/envs/fastai-base/lib/python3.10/site-packages/tensorflow_addons/utils/ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.7.0 and strictly below 2.10.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %% [markdown]
# **Load ONNX model**

# %%
onnx_model = onnx.load(onnx_file_name)

# %% [markdown]
# **Inspect model input**

# %%
onnx_model.graph.input[0]
# Out:
# name: "input"
# type {
#   tensor_type {
#     elem_type: 1
#     shape {
#       dim {
#         dim_value: 1
#       }
#       dim {
#         dim_value: 3
#       }
#       dim {
#         dim_param: "height"
#       }
#       dim {
#         dim_param: "width"
#       }
#     }
#   }
# }

# %% [markdown]
# **Get input name**

# %%
input_name = onnx_model.graph.input[0].name
input_name
# Out:
# 'input'

# %% [markdown]
# **Convert model input to channels-last format**

# %%
onnx_model = order_conversion(
    onnx_graph=onnx_model,
    input_op_names_and_order_dims={f"{input_name}": [0,2,3,1]},
    non_verbose=True
)

# %% [markdown]
# **Inspect updated model input**

# %%
onnx_model.graph.input[0]
# Out:
# name: "input"
# type {
#   tensor_type {
#     elem_type: 1
#     shape {
#       dim {
#         dim_value: 1
#       }
#       dim {
#         dim_param: "height"
#       }
#       dim {
#         dim_param: "width"
#       }
#       dim {
#         dim_value: 3
#       }
#     }
#   }
# }

# %% [markdown]
# **Simplify ONNX model**

# %%
onnx_model, check = simplify(onnx_model)
check
# Out:
# True

# %% [markdown]
# **Prepare ONNX model for Tensorflow Backend**

# %%
tf_rep = prepare(onnx_model)
# Out:
# 2022-09-12 10:19:16.933522: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-12 10:19:16.934083: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-12 10:19:16.934177: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-12 10:19:16.936717: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-12 10:19:16.937451: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-12 10:19:16.937556: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-12 10:19:16.937645: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-12 10:19:17.720356: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-12 10:19:17.720939: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-12 10:19:17.721040: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-12 10:19:17.721120: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 19360 MB memory:  -> device: 0, name: NVIDIA TITAN RTX, pci bus id: 0000:01:00.0, compute capability: 7.5

# %% [markdown]
# **Define path for TensorFlow [saved model](https://www.tensorflow.org/guide/saved_model) directory**

# %%
tf_model_dir = f"./{onnx_file_name.split('.')[0]}"
tf_model_dir
# Out:
# './hagrid-classification-512p-resnet18-opset15'

# %% [markdown]
# **Export backend representation to a Tensorflow proto file**

# %%
tf_rep.export_graph(tf_model_dir)
# Out:
# WARNING:absl:Found untraced functions such as gen_tensor_dict while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./hagrid-classification-512p-resnet18-opset15/assets
# INFO:tensorflow:Assets written to: ./hagrid-classification-512p-resnet18-opset15/assets

# %% [markdown]
# **Define directory path to store tfjs model files**

# %%
tfjs_model_dir = f"{tf_model_dir}-tfjs-uint8"
tfjs_model_dir
# Out:
# './hagrid-classification-512p-resnet18-opset15-tfjs-uint8'

# %% [markdown]
# **Define arguments for tfjs converter script**

# %%
tfjs_convert_command = f"""tensorflowjs_converter
                 --input_format=tf_saved_model 
                 --output_format=tfjs_graph_model 
                 --signature_name=serving_default 
                 --saved_model_tags=serve 
                 "{tf_model_dir}" 
                 "{tfjs_model_dir}"
                 "--quantize_uint8"
                 """
tfjs_convert_command = " ".join(tfjs_convert_command.split())
tfjs_convert_command
# Out:
# 'tensorflowjs_converter --input_format=tf_saved_model --output_format=tfjs_graph_model --signature_name=serving_default --saved_model_tags=serve "./hagrid-classification-512p-resnet18-opset15" "./hagrid-classification-512p-resnet18-opset15-tfjs-uint8" "--quantize_uint8"'

# %% [markdown]
# **Export SavedModel to TFJS format**

# %%
print("Exporting TensorFlow SavedModel to TensorFlow.js Graph model...")
conversion_result = %sx $tfjs_convert_command
print("\n".join(conversion_result))
# Out:
# Exporting TensorFlow SavedModel to TensorFlow.js Graph model...
# 2022-09-12 10:19:22.589316: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-09-12 10:19:22.901930: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-09-12 10:19:22.901964: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-09-12 10:19:22.901968: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2022-09-12 10:19:24.175737: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-09-12 10:19:24.175753: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-09-12 10:19:24.277303: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Writing weight file ./hagrid-classification-512p-resnet18-opset15-tfjs-uint8/model.json...
# weight PartitionedCall/PadV2/paddings with shape (4, 2) and dtype int64 was auto converted to the type int32
# weight unknown_39 with shape (2,) and dtype int64 was auto converted to the type int32
# weight PartitionedCall/Where with shape (0, 1) and dtype int64 was auto converted to the type int32
# weight PartitionedCall/Cast with shape (1,) and dtype int64 was auto converted to the type int32
# weight PartitionedCall/GatherV2 with shape (0,) and dtype int64 was auto converted to the type int32
# weight PartitionedCall/zeros_1 with shape () and dtype int64 was auto converted to the type int32
